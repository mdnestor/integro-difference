# %%
import numpy as np
import matplotlib.pyplot as plt

def growthFunction(a,b,m):
    H = lambda u : np.heaviside(u, 1)
    return lambda u : H(u-a) - (1-m) * H(u-b)

U = np.arange(0, 1, 0.01)
g = growthFunction(a=0.33, b=0.66, m=0.5)
a=0.33
m=0.5
b=0.66

plt.plot([0,1],[0,1],color='black',linestyle='dashed')
plt.plot([0,a],[0,0], color='blue')
plt.plot([a,a],[0,1], color='blue',linestyle='dotted')
plt.plot([a,b],[1,1], color='blue')
plt.plot([b,b],[1,m], color='blue',linestyle='dotted')
plt.plot([b,1],[m,m], color='blue')
plt.plot(0,0,color='blue',marker='o',markersize=5)
plt.plot(a,0,color='blue',marker='o')
plt.plot(a,0,color='white',marker='o',markersize=3)
plt.plot(a,1,color='blue',marker='o',markersize=5)
plt.plot(b,1,color='blue',marker='o',markersize=5)
plt.plot(b,m,color='blue',marker='o',markersize=5)
plt.plot(b,m,color='white',marker='o',markersize=3)
plt.plot(1,m,color='blue',marker='o',markersize=5)
